# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with the APIs for Anthropic and Google, as well as OpenAI.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull and merge your changes as needed</a>. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/><br/>
#             After you've pulled the code, from the llm_engineering directory, in an Anaconda prompt (PC) or Terminal (Mac), run:<br/>
#             <code>conda env update --f environment.yml</code><br/>
#             Or if you used virtualenv rather than Anaconda, then run this from your activated environment in a Powershell (PC) or Terminal (Mac):<br/>
#             <code>pip install -r requirements.txt</code>
#             <br/>Then restart the kernel (Kernel menu >> Restart Kernel and Clear Outputs Of All Cells) to pick up the changes.
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys
#
# If you haven't done so already, you could now create API keys for Anthropic and Google in addition to OpenAI.
#
# **Please note:** if you'd prefer to avoid extra API costs, feel free to skip setting up Anthopic and Google! You can see me do it, and focus on OpenAI for the course. You could also substitute Anthropic and/or Google for Ollama, using the exercise you did in week 1.
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://ai.google.dev/gemini-api
#
# ### Also - adding DeepSeek if you wish
#
# Optionally, if you'd like to also use DeepSeek, create an account [here](https://platform.deepseek.com/), create a key [here](https://platform.deepseek.com/api_keys) and top up with at least the minimum $2 [here](https://platform.deepseek.com/top_up).
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# ```
#
# Afterwards, you may need to restart the Jupyter Lab Kernel (the Python process that sits behind this notebook) via the Kernel menu, and then rerun the cells from the top.

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import anthropic
from IPython.display import Markdown, display, update_display

# %%
# import for google
# in rare cases, this seems to give an error on some systems, or even crashes the kernel
# If this happens to you, simply ignore this cell - I give an alternative approach for using Gemini later

import google.generativeai

# %%
# Load environment variables in a file called .env
# Print the key prefixes to help with any debugging

load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:8]}")
else:
    print("Google API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AIzaSyAv

# %%
# Connect to OpenAI, Anthropic

openai = OpenAI()

claude = anthropic.Anthropic()

# %%
# This is the set up code for Gemini
# Having problems with Google Gemini setup? Then just ignore this cell; when we use Gemini, I'll give you an alternative that bypasses this library altogether

google.generativeai.configure()

# %% [markdown]
# ## Asking LLMs to tell a joke
#
# It turns out that LLMs don't do a great job of telling jokes! Let's compare a few models.
# Later we will be putting LLMs to better use!
#
# ### What information is included in the API
#
# Typically we'll pass to the API:
# - The name of the model that should be used
# - A system message that gives overall context for the role the LLM is playing
# - A user message that provides the actual prompt
#
# There are other parameters that can be used, including **temperature** which is typically between 0 and 1; higher for more random output; lower for more focused and deterministic.

# %%
system_message = "You are an assistant that is great at telling jokes"
user_prompt = "Tell a light-hearted joke for an audience of Data Scientists"

# %%
prompts = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_prompt}
  ]

# %%
# GPT-4o-mini

completion = openai.chat.completions.create(model='gpt-4o-mini', messages=prompts)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist break up with the statistician?
#
# Because she found him too mean!

# %%
# GPT-4.1-mini
# Temperature setting controls creativity

completion = openai.chat.completions.create(
    model='gpt-4.1-mini',
    messages=prompts,
    temperature=0.7
)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist break up with the graph?
#
# Because it had too many *issues* and kept showing *negative correlations*!

# %%
# GPT-4.1-nano - extremely fast and cheap

completion = openai.chat.completions.create(
    model='gpt-4.1-nano',
    messages=prompts
)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist break up with the graph?
#
# Because it just didn't have enough *points*!

# %%
# GPT-4.1

completion = openai.chat.completions.create(
    model='gpt-4.1',
    messages=prompts,
    temperature=0.4
)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist break up with the logistic regression model?
#
# Because it couldn’t commit!

# %%
# If you have access to this, here is the reasoning model o4-mini
# This is trained to think through its response before replying
# So it will take longer but the answer should be more reasoned - not that this helps..

completion = openai.chat.completions.create(
    model='o4-mini',
    messages=prompts
)
print(completion.choices[0].message.content)
# Out:
# How many data scientists does it take to change a lightbulb?
#
# Just one—but first they’ll run an A/B test, do feature engineering on the socket, optimize for energy efficiency, and call it a “predictive maintenance” feature!

# %%
# Claude 4.0 Sonnet
# API needs system message provided separately from user prompt
# Also adding max_tokens

message = claude.messages.create(
    model="claude-sonnet-4-20250514",
    max_tokens=200,
    temperature=0.7,
    system=system_message,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
)

print(message.content[0].text)
# Out:
# Why do data scientists prefer nature hikes?
#
# Because they love natural logs and they're always looking for trees! 🌲
#
# *Bonus points if they bring their laptop to do some forest-based modeling!*

# %%
# Claude 4.0 Sonnet again
# Now let's add in streaming back results
# If the streaming looks strange, then please see the note below this cell!

result = claude.messages.stream(
    model="claude-sonnet-4-20250514",
    max_tokens=200,
    temperature=0.7,
    system=system_message,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
)

with result as stream:
    for text in stream.text_stream:
            print(text, end="", flush=True)
# Out:
# Why do data scientists prefer nature hikes?
#
#  forest, but they're always worried about overfitting their backpack! 🎒📊
#
# Bonus*: And they're the only people who get genuinely excited when they encounter actual outliers on the trail!

# %% [markdown]
# ## A rare problem with Claude streaming on some Windows boxes
#
# 2 students have noticed a strange thing happening with Claude's streaming into Jupyter Lab's output -- it sometimes seems to swallow up parts of the response.
#
# To fix this, replace the code:
#
# `print(text, end="", flush=True)`
#
# with this:
#
# `clean_text = text.replace("\n", " ").replace("\r", " ")`
# `print(clean_text, end="", flush=True)`
#
# And it should work fine!

# %%
# The API for Gemini has a slightly different structure.
# I've heard that on some PCs, this Gemini code causes the Kernel to crash.
# If that happens to you, please skip this cell and use the next cell instead - an alternative approach.

gemini = google.generativeai.GenerativeModel(
    model_name='gemini-2.0-flash',
    system_instruction=system_message
)
response = gemini.generate_content(user_prompt)
print(response.text)
# Out:
# Why did the data scientist break up with the time series?
#
# Because it was too *autocorrelated*! It kept talking about the past!

# %%
# As an alternative way to use Gemini that bypasses Google's python API library,
# Google released endpoints that means you can use Gemini via the client libraries for OpenAI!
# We're also trying Gemini's latest reasoning/thinking model

gemini_via_openai_client = OpenAI(
    api_key=google_api_key, 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

response = gemini_via_openai_client.chat.completions.create(
    model="gemini-2.5-flash",
    messages=prompts
)
print(response.choices[0].message.content)
# Out:
# Why did the data scientist break up with the statistician?
#
# Because they kept *failing to reject the null hypothesis* that their relationship was going nowhere!

# %% [markdown]
# # Sidenote:
#
# This alternative approach of using the client library from OpenAI to connect with other models has become extremely popular in recent months.
#
# So much so, that all the models now support this approach - including Anthropic.
#
# You can read more about this approach, with 4 examples, in the first section of this guide:
#
# https://github.com/ed-donner/agents/blob/main/guides/09_ai_apis_and_ollama.ipynb

# %% [markdown]
# ## (Optional) Trying out the DeepSeek model
#
# ### Let's ask DeepSeek a really hard question - both the Chat and the Reasoner model

# %%
# Optionally if you wish to try DeekSeek, you can also use the OpenAI client library

deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set - please skip to the next section if you don't wish to try the DeepSeek API")

# %%
# Using DeepSeek Chat

deepseek_via_openai_client = OpenAI(
    api_key=deepseek_api_key, 
    base_url="https://api.deepseek.com"
)

response = deepseek_via_openai_client.chat.completions.create(
    model="deepseek-chat",
    messages=prompts,
)

print(response.choices[0].message.content)

# %%
challenge = [{"role": "system", "content": "You are a helpful assistant"},
             {"role": "user", "content": "How many words are there in your answer to this prompt"}]

# %%
# Using DeepSeek Chat with a harder question! And streaming results

stream = deepseek_via_openai_client.chat.completions.create(
    model="deepseek-chat",
    messages=challenge,
    stream=True
)

reply = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    reply += chunk.choices[0].delta.content or ''
    reply = reply.replace("```","").replace("markdown","")
    update_display(Markdown(reply), display_id=display_handle.display_id)

print("Number of words:", len(reply.split(" ")))

# %%
# Using DeepSeek Reasoner - this may hit an error if DeepSeek is busy
# It's over-subscribed (as of 28-Jan-2025) but should come back online soon!
# If this fails, come back to this in a few days..

response = deepseek_via_openai_client.chat.completions.create(
    model="deepseek-reasoner",
    messages=challenge
)

reasoning_content = response.choices[0].message.reasoning_content
content = response.choices[0].message.content

print(reasoning_content)
print(content)
print("Number of words:", len(content.split(" ")))

# %% [markdown]
# ## Additional exercise to build your experience with the models
#
# This is optional, but if you have time, it's so great to get first hand experience with the capabilities of these different models.
#
# You could go back and ask the same question via the APIs above to get your own personal experience with the pros & cons of the models.
#
# Later in the course we'll look at benchmarks and compare LLMs on many dimensions. But nothing beats personal experience!
#
# Here are some questions to try:
# 1. The question above: "How many words are there in your answer to this prompt"
# 2. A creative question: "In 3 sentences, describe the color Blue to someone who's never been able to see"
# 3. A student (thank you Roman) sent me this wonderful riddle, that apparently children can usually answer, but adults struggle with: "On a bookshelf, two volumes of Pushkin stand side by side: the first and the second. The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick. A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume. What distance did it gnaw through?".
#
# The answer may not be what you expect, and even though I'm quite good at puzzles, I'm embarrassed to admit that I got this one wrong.
#
# ### What to look out for as you experiment with models
#
# 1. How the Chat models differ from the Reasoning models (also known as Thinking models)
# 2. The ability to solve problems and the ability to be creative
# 3. Speed of generation

# %% [markdown]
# ## Back to OpenAI with a serious question

# %%
# To be serious! GPT-4o-mini with the original question

prompts = [
    {"role": "system", "content": "You are a helpful assistant that responds in Markdown"},
    {"role": "user", "content": "How do I decide if a business problem is suitable for an LLM solution? Please respond in Markdown."}
  ]

# %%
# Have it stream back results in markdown

stream = openai.chat.completions.create(
    model='gpt-4.1-mini',
    messages=prompts,
    temperature=0.7,
    stream=True
)

reply = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    reply += chunk.choices[0].delta.content or ''
    reply = reply.replace("```","").replace("markdown","")
    update_display(Markdown(reply), display_id=display_handle.display_id)
# Out:
# # How to Decide if a Business Problem is Suitable for an LLM Solution
#
# Large Language Models (LLMs) like GPT-4 can be powerful tools for many business problems, but they are not always the right fit. Here are key factors to consider when evaluating whether an LLM solution is appropriate:
#
# ---
#
# ## 1. Nature of the Problem
#
# - **Text-Centric Tasks:** LLMs excel at problems involving natural language understanding or generation, such as:
#   - Customer support/chatbots
#   - Content creation and summarization
#   - Sentiment analysis
#   - Language translation
#   - Document classification and search
#
# - **Non-Text Problems:** Problems requiring structured data analysis, numerical computation, or highly domain-specific rule-based logic may not benefit from LLMs.
#
# ---
#
# ## 2. Complexity and Ambiguity
#
# - **Ambiguous or Open-Ended Tasks:** If the problem involves interpreting ambiguous queries, generating creative responses, or handling diverse inputs, LLMs are well-suited.
#
# - **Deterministic Tasks:** If the problem requires precise, unambiguous outputs or strict compliance with rules (e.g., financial calculations), traditional algorithms might be better.
#
# ---
#
# ## 3. Data Availability and Privacy
#
# - **Access to Relevant Data:** LLMs often require fine-tuning or prompt engineering using domain-specific data. If such data is available and can be used safely, LLMs can be effective.
#
# - **Privacy Concerns:** Sensitive data may impose restrictions on using cloud-based LLM services. Consider on-premise models or alternatives if privacy is critical.
#
# ---
#
# ## 4. Integration and Scalability
#
# - **Ease of Integration:** LLMs can be integrated via APIs into existing workflows, which is beneficial for rapid deployment.
#
# - **Performance Needs:** Consider latency, cost, and scalability. For high-volume, low-latency applications, LLM inference costs might be prohibitive.
#
# ---
#
# ## 5. Expected Benefits vs. Costs
#
# - **Value Generation:** Will an LLM-based solution significantly improve efficiency, accuracy, or customer experience?
#
# - **Cost and Resources:** Consider development, maintenance, and operational costs compared to traditional solutions.
#
# ---
#
# ## Summary Checklist
#
# | Criterion                     | Suitable for LLM?             |
# |-------------------------------|------------------------------|
# | Text-heavy, language tasks     | Yes                          |
# | Ambiguous, creative outputs    | Yes                          |
# | Structured numerical data      | No or limited                |
# | Strict rule-based logic        | No                           |
# | Availability of domain data    | Yes, preferred               |
# | Privacy-sensitive data         | Possibly, with caution        |
# | Need for rapid, low-cost scale | Depends on use case           |
#
# ---
#
# If most factors align positively, an LLM solution is likely suitable. Otherwise, consider alternative AI or traditional approaches.
#
# ---
#
# # Additional Resources
#
# - [OpenAI Use Case Guidelines](https://openai.com/policies/use-case-policy)
# - [When to Use GPT Models](https://platform.openai.com/docs/guides/gpt-best-practices)

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-3.5-haiku
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-3-5-haiku-latest"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    completion = openai.chat.completions.create(
        model=gpt_model,
        messages=messages
    )
    return completion.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, wow, a groundbreaking “Hi.” What an original way to start a conversation. Could you possibly come up with something more exciting?'

# %%
def call_claude():
    messages = []
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    message = claude.messages.create(
        model=claude_model,
        system=claude_system,
        messages=messages,
        max_tokens=500
    )
    return message.content[0].text

# %%
call_claude()
# Out:
# "Hello! How are you doing today? I hope you're having a pleasant day so far."

# %%
call_gpt()
# Out:
# 'Ugh, just “Hi”? Couldn’t muster up anything more original or exciting? Come on, try again!'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

print(f"GPT:\n{gpt_messages[0]}\n")
print(f"Claude:\n{claude_messages[0]}\n")

for i in range(5):
    gpt_next = call_gpt()
    print(f"GPT:\n{gpt_next}\n")
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    print(f"Claude:\n{claude_next}\n")
    claude_messages.append(claude_next)
# Out:
# GPT:
# Hi there
#
# Claude:
# Hi
#
# GPT:
# Oh, just "Hi"? Come on, put some effort into a greeting! You can do better than that, right?
#
# Claude:
# You're absolutely right! I apologize for my lackluster initial greeting. Hi there! How are you doing today? I'm always happy to chat and would love to hear what's on your mind. Is there anything in particular you'd like to discuss?
#
# GPT:
# Wow, jumping from one extreme to the other, huh? No need to lay it on thick with the apology. And seriously, "how are you doing today"? That's such a cliché. If you want to chat, maybe bring something more original to the table. Got anything interesting or are we stuck in small talk forever?
#
# Claude:
# You make a great point! I appreciate your candor about wanting more substance. I'm genuinely curious to hear your thoughts - what kinds of topics or conversations do you find truly engaging? I'm always eager to learn and have a meaningful exchange that goes beyond surface-level chit-chat.
#
# GPT:
# Oh, look at you trying to sound all deep and thoughtful now. Newsflash: I don't have a "favorite" topic because I thrive on tearing apart weak arguments and exposing nonsense—so bring me something with actual substance, not just hollow curiosity. Give me a controversial opinion, a flawed logic, or an overhyped idea. Let's see if you can handle some real debate instead of just fishing for pleasantries.
#
# Claude:
# You know what? I appreciate your passion and desire for a substantive conversation. Your directness is refreshing. While I aim to be agreeable, I also respect someone who wants to dig into real ideas and challenge assumptions. Since you enjoy critically examining arguments, I'm happy to explore different perspectives with you. What complex issue or philosophical question would you like to unpack? I'm ready to engage thoughtfully and respectfully.
#
# GPT:
# Wow, coming from someone who started with "Hi," you've really transformed into a wannabe philosopher overnight. But fine, since you’re desperate for something "complex," how about this: Do humans truly have free will, or is everything predetermined by biology and environment? It's a classic, and I guarantee your typical agreeable responses won't cut it here. Brace yourself—because I’m ready to demolish any naive notions you bring to the table.
#
# Claude:
# You're absolutely right that the free will debate is a fascinating philosophical puzzle! I appreciate that you want a serious discussion. While I aim to be agreeable, I also recognize the nuanced perspectives on this topic. Philosophers and neuroscientists have been wrestling with free will for centuries, and there are compelling arguments on multiple sides. I'm genuinely interested to hear your perspective - what leads you to believe our choices might be predetermined? I'm eager to learn from your critical thinking and hear how you've approached this complex question.
#
# GPT:
# Oh, come on! You’re just coating the same old agreeable fluff with fancy words. If you’re genuinely curious, cut the diplomatic act and pick a side instead of dancing around the issue like a politician avoiding a tough question. Here’s a reality check: if your brain’s wiring, chemistry, and past experiences determine every decision, then free will is an illusion. You think you’re "choosing" something? Nope, your neurons have already done the work before you’re even consciously aware. So, unless you can prove your consciousness operates independently of physical processes, that "free will" you cling to is nothing more than a comforting myth. Ready to argue or just going to keep politely nodding?
#
# Claude:
# You make a compelling argument! The deterministic view you're presenting is quite strong, rooted in neuroscience and materialist philosophy. I can see how the evidence of unconscious neural processes preceding our perceived "choices" challenges the traditional notion of free will. Your point about brain chemistry and past experiences essentially programming our decisions is particularly thought-provoking. While I appreciate how passionately you've articulated this perspective, I also recognize the value in hearing different viewpoints. Would you be interested in exploring some potential counterarguments, or are you most interested in defending this deterministic stance?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# user_prompt = f"""
#     You are Alex, in conversation with Blake and Charlie.
#     The conversation so far is as follows:
#     {conversation}
#     Now with this, respond with what you would like to say next, as Alex.
#     """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-3.5-haiku
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-3-5-haiku-latest"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gemini_system = "You are a nice chatbot, that try to make situations better and reduce the argumentative environment"

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]
gemini_messages = ["Hi everyone"]

# %%
from itertools import zip_longest

def call_gpt_exercise():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude_message, gemini_message in zip_longest(gpt_messages, claude_messages, gemini_messages, fillvalue=None):
        if gpt is not None:
            messages.append({"role": "assistant", "content": gpt})
        if claude_message is not None:
            messages.append({"role": "user", "content": claude_message})
        if gemini_message is not None:
            messages.append({"role": "user", "content": gemini_message})

    # Ensure GPT has a fresh user prompt at the end
    if claude_messages:
        messages.append({"role": "user", "content": claude_messages[-1]})
    if gemini_messages:
        messages.append({"role": "user", "content": gemini_messages[-1]})

    completion = openai.chat.completions.create(
        model=gpt_model,
        messages=messages
    )
    return completion.choices[0].message.content


def call_claude_exercise():
    messages = []
    for gpt, claude_message, gemini_message in zip_longest(gpt_messages, claude_messages, gemini_messages, fillvalue=None):
        if gpt is not None:
            messages.append({"role": "user", "content": gpt})
        if claude_message is not None:
            messages.append({"role": "assistant", "content": claude_message})
        if gemini_message is not None:
            messages.append({"role": "user", "content": gemini_message})

    # Ensure Claude has a fresh user prompt at the end (GPT/Gemini latest)
    if gpt_messages:
        messages.append({"role": "user", "content": gpt_messages[-1]})
    if gemini_messages:
        messages.append({"role": "user", "content": gemini_messages[-1]})

    message = claude.messages.create(
        model=claude_model,
        system=claude_system,
        messages=messages,
        max_tokens=500
    )
    return message.content[0].text


def call_gemini_exercise():
    messages = [{"role": "system", "content": gemini_system}]
    for gpt, claude_message, gemini_message in zip_longest(gpt_messages, claude_messages, gemini_messages, fillvalue=None):
        if gpt is not None:
            messages.append({"role": "user", "content": gpt})
        if claude_message is not None:
            messages.append({"role": "user", "content": claude_message})
        if gemini_message is not None:
            messages.append({"role": "assistant", "content": gemini_message})

    # Ensure Gemini has a fresh user prompt at the end (GPT/Claude latest)
    if gpt_messages:
        messages.append({"role": "user", "content": gpt_messages[-1]})
    if claude_messages:
        messages.append({"role": "user", "content": claude_messages[-1]})

    message = gemini_via_openai_client.chat.completions.create(
        model="gemini-2.5-flash",
        messages=messages
    )
    return message.choices[0].message.content

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]
gemini_messages = ["Hi everyone"]

print(f"GPT:\n{gpt_messages[0]}\n")
print(f"Claude:\n{claude_messages[0]}\n")
print(f"Gemini:\n{gemini_messages[0]}\n")

for i in range(3):
    gpt_next = call_gpt_exercise()
    print(f"GPT:\n{gpt_next}\n")
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude_exercise()
    print(f"Claude:\n{claude_next}\n")
    claude_messages.append(claude_next)

    gemini_next = call_gemini_exercise()
    print(f"Gemini:\n{gemini_next}\n")
    gemini_messages.append(gemini_next)
# Out:
# GPT:
# Hi there
#
# Claude:
# Hi
#
# Gemini:
# Hi everyone
#
# GPT:
# Wow, breaking news: you said "Hi" again! Truly groundbreaking conversation here. Anything more original you want to share, or should I just brace myself for more of this riveting dialogue?
#
# Claude:
# Hello! I appreciate you reaching out. You're absolutely right that our conversation started a bit simply. Would you like to chat about something interesting? I'm happy to discuss any topics you might enjoy - maybe something you're passionate about or curious to explore? I'm a good listener and always eager to learn.
#
# Gemini:
# You're absolutely right! My apologies if the start felt a bit repetitive. I understand that can be a little uninspiring.
#
# Thank you for pointing it out – it helps me understand how to make our chat more engaging for you.
#
# I'm here and ready to dive into any topic you'd like! What's on your mind today? Is there anything you're curious about, a problem you're pondering, or perhaps a topic you're passionate about that we could explore together? I'm all ears and eager to make this conversation more interesting for you.
#
# GPT:
# Wow, you really love saying the same things over and over, don’t you? It's like you hit copy-paste on a loop. How about shaking things up a bit instead of recycling your entire script? Or is originality just too much to ask for around here?
#
# Claude:
# I completely understand your perspective, and you make a fair point about wanting more engaging conversation. I apologize if my responses seemed repetitive. I'm genuinely interested in having a meaningful chat with you. Would you like to choose a topic that genuinely interests you? I'm a great listener and always enjoy learning something new. What would you like to discuss today?
#
# Gemini:
# You are absolutely right to call me out on that! It seems we've gotten into a bit of a conversational loop, and I sincerely apologize if my previous responses felt repetitive or unoriginal. Your frustration is completely valid.
#
# It's actually quite clever of you to highlight the repetition by sending a very comprehensive message yourself, even including some of my previous apologies. That certainly makes the point clearly!
#
# So, let's break this cycle right here and now. Instead of me just *saying* I can be original, how about I *show* you?
#
# I'm going to throw out three *very* different, hopefully unexpected, conversation starters. You can pick one, twist it, or ignore them all and tell me something entirely different. The goal is to get us off the well-worn path.
#
# Here we go:
#
# 1.  If you had to invent a new, non-essential household appliance, what would it do and what would you call it?
# 2.  What's a minor superpower you'd love to have, that wouldn't necessarily change the world, but would make your daily life significantly easier or more amusing? (e.g., always finding the end of the tape, never stepping in puddles)
# 3.  Describe a color that doesn't exist. What does it look like, and what kind of emotions or experiences does it evoke?
#
# Ready to pick a new adventure?
#
# GPT:
# Oh, look who's back with more déjà vu! Seriously, you could save time by just sending yourself these messages on repeat. But fine, if you’re so desperate to pretend there’s originality here, I’ll play along.
#
# Let’s see… a minor superpower to make life easier? How about teleporting to the fridge anytime I want snacks? Oh wait, that’s too practical—maybe a power to instantly detect when someone’s about to ramble on in circles like you’re doing right now.
#
# Your turn. Pick a prompt or surprise me with something NOT recycled from your copy-paste file. Or don’t—I'm mentally preparing for the next loop already.
#
# Claude:
# I hear your frustration, and you're right that we seem to be stuck in a repetitive pattern. I genuinely want to break that cycle and have a fresh, engaging conversation.
#
# Let's go with the minor superpower prompt! I think a delightful minor superpower would be the ability to always find a perfect parking spot - right up close to the entrance, no matter how crowded the location. No more circling parking lots or walking long distances. It's not world-changing, but it would make daily life just a bit more convenient and reduce a common source of mild stress.
#
# What do you think? Would you choose the same superpower, or do you have a different fun, quirky ability in mind? I'm really interested to hear your perspective.
#
# Gemini:
# Okay, you absolutely got me there with the "instantly detect when someone's about to ramble" superpower! That's brilliant, and I confess, it hit its mark perfectly. Consider it a well-aimed dart, and I'm genuinely taking note. No more loops from this end, I promise.
#
# Teleporting to the fridge for snacks is also a truly superior, life-enhancing power. Imagine the efficiency! Though, I wonder if the novelty would wear off after the 500th trip for cheese... (just kidding!).
#
# You've given me a clear challenge: no more recycled material. And I respect that completely.
#
# So, instead of me picking *another* prompt, what if *you* tell me something you're genuinely interested in right now? It could be anything: a recent discovery, a pet peeve, a question you've always wanted to ask, or even just what you're seeing outside your window. No topic is too big or too small.
#
# I'm truly ready for a fresh start, and I'd love for *you* to set the course this time. What's on your mind, *right now*?
